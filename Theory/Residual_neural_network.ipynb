# %% [markdown]
# ## Residual neural network
# - A **residual neural network** (ResNet) is a deep learning architecture in which the layers learn residual functions with reference to the layer inputs.
#
# - It was developed in 2015 for image recognition, winning the **ImageNet Large Scale Visual Recognition Challenge** of that year.

# %% [markdown]
# #### Terminology
# - A "residual connection" refers to the specific architectural motif of x -> f(x) + X, where f is an arbitrary neural network module.
#
# - It stabilizes the training and convergence of deep neural networks with hundreds of layers, and is a common motif in deep neural networks, such as transformer models (like BERT and GPT models).

# %% [markdown]
# #### Applications
# - Originally, ResNet was designed for computer vision.
#
# - All transformer architectures include residual connections, very deep transformers cannot be trained without them.
